# %% [markdown]
# # 05 - Master notebook
#
# Rubric: *"a master notebook that executes the whole workflow"*.
#
# Running this top-to-bottom reproduces every result in the project README.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from smaz import backtest, utils
from algotrade import ingest, model, strategy, transform

utils.set_plot_defaults()
pd.set_option("display.max_columns", 80)

# %% [markdown]
# ## Run the full pipeline
#
# Same code path as the cron job -- no notebook-only logic.

# %%
import subprocess, sys
from smaz.config import REPO_ROOT

subprocess.run(
    [sys.executable, str(REPO_ROOT / "project" / "scripts" / "run_pipeline.py"), "--mode", "file"],
    check=True,
)

# %% [markdown]
# ## Headline results
#
# <!-- Paste the final metrics table and the conclusion here. -->
